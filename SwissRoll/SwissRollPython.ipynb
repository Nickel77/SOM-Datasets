# %%
from sklearn.datasets import make_swiss_roll
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# Use the make_swiss_roll function to generate a dataset
x, t = make_swiss_roll(n_samples=5000)
# The printed array is in x, z, y order
print(x)
# Out:
# [[  5.80480912   4.07245842  12.40901797]
#  [ 10.72265218   5.95085286  -5.57789793]
#  [ -5.27373522   9.50980685   6.69331042]
#  ...
#  [  2.60820974  16.16629749 -10.92288644]
#  [  6.22785753  13.83496327   2.29004514]
#  [ -9.42198947  14.37580074  -2.01889121]]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
#ax.plot3D(x[0], x[1], x[2], 'gray')
#ax = fig.add_subplot(211, projection="3d")
ax.scatter(x[:, 0], x[:, 2], x[:, 1], c=t, cmap=plt.cm.Spectral)
