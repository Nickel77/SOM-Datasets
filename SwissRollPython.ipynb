# %%
from sklearn.datasets import make_swiss_roll
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# Use the make_swiss_roll function to generate a dataset
x, t = make_swiss_roll(n_samples=5000)
# The printed array is in x, z, y order
print(x)
# Out:
# [[-7.63722895 14.34328908 -6.67487244]
#  [ 6.08385057  0.16414806 -0.85475945]
#  [-3.15281724  3.34748282  7.6197899 ]
#  ...
#  [-4.15774718  0.47597083 -9.74205917]
#  [ 3.48394622  3.37143329 -4.14122141]
#  [ 5.57161749 17.65726843 -2.03773628]]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
#ax.plot3D(x[0], x[1], x[2], 'gray')
#ax = fig.add_subplot(211, projection="3d")
ax.scatter(x[:, 0], x[:, 2], x[:, 1], c=t, cmap=plt.cm.Spectral)
